# %% [markdown]
# 2 Getting Started with Image Processing with Python.
# Introduction to Python Imaging Library(PIL)
# 2.1 Exercise - 1:
# Complete all the Task.
# 1. Read and display the image.
# • Read the image using the Pillow library and display it.
# • You can also use matplotlib to display the image.

# %%
from PIL import Image
# display image in colab
image_colored = Image.open("Lenna_(test_image).png")
display( image_colored )
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %% [markdown]
# 2. Display only the top left corner of 100x100 pixels.
# • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
# Array Indexing.

# %%
print ( " Image Format : " , image_colored.format )
print ( " Image Size : " , image_colored.size )
print ( " Image Mode : " , image_colored.mode )
# Out:
#  Image Format :  PNG
#  Image Size :  (512, 512)
#  Image Mode :  RGB

# %% [markdown]
# 3. Show the three color channels (R, G, B).
# • Separate the image into its three color channels (Red, Green, and Blue) and display them
# individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
# Get the size (width , height ) and channels (RGB)
width , height = image_colored . size
channels = len(image_colored.getbands()) # For RGB , it will be 3
print( f" Image shape (RGB): ({ height } , { width } , { channels})")
image_size_colored = width * height *3
print ( f" Image size (RGB): { image_size_colored }")
# Out:
#  Image shape (RGB): (512 , 512 , 3)
#  Image size (RGB): 786432

# %% [markdown]
# 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
# • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a
# light gray color), and then display the modified image.

# %%
import numpy as np

# Convert the Pillow image to a NumPy array
image_array_colored = np.array(image_colored)
# Display the shape of the NumPy array (height , width ,channels )
print (" Shape of the image array :", image_array_colored.shape )
# Out:
#  Shape of the image array : (512, 512, 3)

# %%
# Convert the Pillow image to a NumPy array
image_array_colored = np.array(image_colored)

#For Red Channels
red_channel = image_array_colored.copy()
red_channel[:,:,1]=0
red_channel[:,:,2]=0
print ("Red Channel image: ")
display ( red_channel )
# Out:
# Red Channel image:
# array([[[226,   0,   0],
#         [226,   0,   0],
#         [223,   0,   0],
#         ...,
#         [230,   0,   0],
#         [221,   0,   0],
#         [200,   0,   0]],
#
#        [[226,   0,   0],
#         [226,   0,   0],
#         [223,   0,   0],
#         ...,
#         [230,   0,   0],
#         [221,   0,   0],
#         [200,   0,   0]],
#
#        [[226,   0,   0],
#         [226,   0,   0],
#         [223,   0,   0],
#         ...,
#         [230,   0,   0],
#         [221,   0,   0],
#         [200,   0,   0]],
#
#        ...,
#
#        [[ 84,   0,   0],
#         [ 84,   0,   0],
#         [ 92,   0,   0],
#         ...,
#         [173,   0,   0],
#         [172,   0,   0],
#         [177,   0,   0]],
#
#        [[ 82,   0,   0],
#         [ 82,   0,   0],
#         [ 96,   0,   0],
#         ...,
#         [179,   0,   0],
#         [181,   0,   0],
#         [185,   0,   0]],
#
#        [[ 82,   0,   0],
#         [ 82,   0,   0],
# ...

# %%
#For Green Channels
green_channel = image_array_colored.copy()
green_channel[:,:,0]=0
green_channel[:,:,2]=0
print ("Red Channel image: ")
display ( green_channel )
# Out:
# Red Channel image:
# array([[[  0, 137,   0],
#         [  0, 137,   0],
#         [  0, 137,   0],
#         ...,
#         [  0, 148,   0],
#         [  0, 130,   0],
#         [  0,  99,   0]],
#
#        [[  0, 137,   0],
#         [  0, 137,   0],
#         [  0, 137,   0],
#         ...,
#         [  0, 148,   0],
#         [  0, 130,   0],
#         [  0,  99,   0]],
#
#        [[  0, 137,   0],
#         [  0, 137,   0],
#         [  0, 137,   0],
#         ...,
#         [  0, 148,   0],
#         [  0, 130,   0],
#         [  0,  99,   0]],
#
#        ...,
#
#        [[  0,  18,   0],
#         [  0,  18,   0],
#         [  0,  27,   0],
#         ...,
#         [  0,  73,   0],
#         [  0,  68,   0],
#         [  0,  62,   0]],
#
#        [[  0,  22,   0],
#         [  0,  22,   0],
#         [  0,  32,   0],
#         ...,
#         [  0,  70,   0],
#         [  0,  71,   0],
#         [  0,  74,   0]],
#
#        [[  0,  22,   0],
#         [  0,  22,   0],
# ...

# %%
# for blue channel
blue_channel = image_array_colored.copy()
blue_channel[:,:,0]=0
blue_channel[:,:,1]=0
print ("Red Channel image: ")
display ( blue_channel )
# Out:
# Red Channel image:
# array([[[  0,   0, 125],
#         [  0,   0, 125],
#         [  0,   0, 133],
#         ...,
#         [  0,   0, 122],
#         [  0,   0, 110],
#         [  0,   0,  90]],
#
#        [[  0,   0, 125],
#         [  0,   0, 125],
#         [  0,   0, 133],
#         ...,
#         [  0,   0, 122],
#         [  0,   0, 110],
#         [  0,   0,  90]],
#
#        [[  0,   0, 125],
#         [  0,   0, 125],
#         [  0,   0, 133],
#         ...,
#         [  0,   0, 122],
#         [  0,   0, 110],
#         [  0,   0,  90]],
#
#        ...,
#
#        [[  0,   0,  60],
#         [  0,   0,  60],
#         [  0,   0,  58],
#         ...,
#         [  0,   0,  84],
#         [  0,   0,  76],
#         [  0,   0,  79]],
#
#        [[  0,   0,  57],
#         [  0,   0,  57],
#         [  0,   0,  62],
#         ...,
#         [  0,   0,  79],
#         [  0,   0,  81],
#         [  0,   0,  81]],
#
#        [[  0,   0,  57],
#         [  0,   0,  57],
# ...

# %%
modified_image_array = image_array_colored[:100,:100]
display(modified_image_array)
# Out:
# array([[[226, 137, 125],
#         [226, 137, 125],
#         [223, 137, 133],
#         ...,
#         [179,  79,  86],
#         [178,  78,  93],
#         [174,  78,  87]],
#
#        [[226, 137, 125],
#         [226, 137, 125],
#         [223, 137, 133],
#         ...,
#         [179,  79,  86],
#         [178,  78,  93],
#         [174,  78,  87]],
#
#        [[226, 137, 125],
#         [226, 137, 125],
#         [223, 137, 133],
#         ...,
#         [179,  79,  86],
#         [178,  78,  93],
#         [174,  78,  87]],
#
#        ...,
#
#        [[177,  64,  79],
#         [177,  64,  79],
#         [163,  58,  74],
#         ...,
#         [177,  65,  79],
#         [172,  68,  79],
#         [172,  75,  83]],
#
#        [[169,  63,  79],
#         [169,  63,  79],
#         [159,  53,  74],
#         ...,
#         [175,  70,  85],
#         [178,  72,  84],
#         [178,  63,  75]],
#
#        [[166,  55,  74],
#         [166,  55,  74],
#         [154,  51,  71],
# ...

# %%
image_array=np.array(image_colored)
image_array[:100,:100] = [210,210,210]
image_210 = Image.fromarray(image_array)
display(image_210)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# 2.2 Exercise - 2:
# Complete all the Task.
# 1. Load and display a grayscale image.
# • Load a grayscale image using the Pillow library.
# • Display the grayscale image using matplotlib.

# %%
# Load the grayscale image using Pillow
image_gray = Image.open('cameraman.png').convert('L')
display(image_gray)
# Display the grayscale image using Matplotlib
plt.imshow(image_gray, cmap='gray')
plt.axis('off')  # Hide axis
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %% [markdown]
# 2. Extract and display the middle section of the image (150 pixels).
# • Extract a 150 pixel section from the center of the image using NumPy array slicing.
# • Display this cropped image using matplotlib.

# %%
# Convert the image to a NumPy array
image_array_gray = np.array(image_gray)

# Get the dimensions of the image
height, width = image_array_gray.shape

# Calculate the coordinates of the middle section
top = height // 2 - 75
bottom = height // 2 + 75
left = width // 2 - 75
right = width // 2 + 75

# Extract the middle 150x150 pixels
middle_section = image_array_gray[top:bottom, left:right]

# Display the extracted middle section
display(middle_section)
# Out:
# array([[  9,   9,   9, ..., 167, 166, 166],
#        [ 11,  11,  10, ..., 165, 164, 165],
#        [ 13,  13,  12, ..., 165, 164, 165],
#        ...,
#        [ 11,  12,  13, ...,  34,  34,  31],
#        [ 12,  13,  13, ...,  22,  34,  42],
#        [ 13,  13,  12, ...,  15,  33,  48]], dtype=uint8)

# %% [markdown]
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
# • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
# above 100 to 255 (creating a binary image).
# • Display the resulting binary image.

# %%
# Apply a simple threshold (set all values below 100 to 0, above 100 to 255)
threshold_image = np.where(image_array_gray < 100, 0, 255)

# Display the resulting binary image
plt.imshow(threshold_image, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# 4. Rotate the image 90 degrees clockwise and display the result.
# • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating
# the image array.
# • Display the rotated image using matplotlib.

# %%
# Rotate the image by 90 degrees clockwise using Pillow
rotated_image = image_gray.rotate(-90, expand=True)

# Display the rotated image
plt.imshow(rotated_image, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# 5. Convert the grayscale image to an RGB image.
# • Convert the grayscale image into an RGB image where the grayscale values are replicated
# across all three channels (R, G, and B).
# • Display the converted RGB image using matplotlib.

# %%
# Convert the grayscale image to RGB
image_rgb = image_gray.convert('RGB')

# Display the converted RGB image
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
# Load the image and convert to grayscale
image_pca = image.convert('L')
image_array = np.array(image_pca)

# Display the original image
plt.imshow(image_array, cmap='gray')
plt.title("Original Image")
plt.axis('off')
plt.show()

# Standardize the data (Center the data by subtracting the mean)
mean = np.mean(image_array, axis=1, keepdims=True)
centered_data = image_array - mean

# Calculate the covariance matrix (we use the formula cov(X) = (X.T * X) / (n-1))
cov_matrix = np.cov(centered_data.T)

# %% [markdown]
# 3 Image Compression and Decompression using PCA.
# In this exercise, build a PCA from scratch using explained variance method for image compression task.
# You are expected to compute the necessary matrices from the scratch. Dataset: Use image of your
# choice.

# %% [markdown]
# 1. Load and Prepare Data:
# • Fetch an image of you choice.{If colour convert to grayscale}
# • Center the dataset - Standaridze the Data.
# • Calculate the covaraince matrix of the Standaridze data.

# %%
# Import necessary libraries
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Step 1: Load and Prepare the Data
# Load the image (replace 'cameraman.png' with your image path)
image_path = 'cameraman.png'
image = Image.open(image_path).convert('L')  # Convert to grayscale if not already
image = np.array(image)  # Convert image to numpy array

# Display the original image
plt.imshow(image, cmap='gray')
plt.title("Original Image")
plt.axis('off')
plt.show()

# Standardize the data (center the dataset)
image_standardized = image - np.mean(image, axis=0)  # Subtract mean to center the data

# Step 2: Calculate the Covariance Matrix
cov_matrix = np.cov(image_standardized, rowvar=False)  # Compute covariance matrix

# Step 3: Compute Eigenvalues and Eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)  # Eigen decomposition

# Sort eigenvalues and eigenvectors in descending order
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# Step 4: Select Top k Principal Components Based on Explained Variance
explained_variance = eigenvalues / np.sum(eigenvalues)  # Calculate explained variance
cumulative_explained_variance = np.cumsum(explained_variance)  # Cumulative explained variance

# Choose the number of components (k) to retain (e.g., 95% variance)
k = np.argmax(cumulative_explained_variance >= 0.95) + 1
print(f"Number of components to retain: {k}")

# Select the top k eigenvectors
top_k_eigenvectors = eigenvectors[:, :k]

# Step 5: Compress the Image
compressed_data = np.dot(image_standardized, top_k_eigenvectors)  # Project data onto top k components

# Step 6: Reconstruct the Image
reconstructed_data = np.dot(compressed_data, top_k_eigenvectors.T)  # Reconstruct data
reconstructed_image = reconstructed_data + np.mean(image, axis=0)  # Add mean back

# Clip values to ensure they are within the valid range [0, 255]
reconstructed_image = np.clip(reconstructed_image, 0, 255).astype(np.uint8)

# Step 7: Display the Reconstructed Image
plt.imshow(reconstructed_image, cmap='gray')
plt.title(f"Reconstructed Image (k={k})")
plt.axis('off')
plt.show()

# Step 8: Compare Original and Reconstructed Images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(reconstructed_image, cmap='gray')
plt.title(f"Reconstructed Image (k={k})")
plt.axis('off')

plt.show()
# Out:
# Number of components to retain: 26

# %%
# Eigen decomposition of the covariance matrix
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

# Sort eigenvalues in descending order and get corresponding eigenvectors
sorted_indices = np.argsort(eigenvalues)[::-1]  # Sort in descending order
sorted_eigenvalues = eigenvalues[sorted_indices]
sorted_eigenvectors = eigenvectors[:, sorted_indices]

# %%
# Compute the explained variance ratio
explained_variance = sorted_eigenvalues / np.sum(sorted_eigenvalues)

# Compute the cumulative explained variance
cumulative_explained_variance = np.cumsum(explained_variance)

# Plot the cumulative explained variance
plt.plot(cumulative_explained_variance)
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Cumulative Explained Variance by Principal Components")
plt.show()
